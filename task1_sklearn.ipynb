# %%
import pandas as pd
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
from datetime import datetime
from tqdm import tqdm
from colorama import Fore, Back
from sklearn import linear_model
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## read the dataset

# %%
X_set = pd.read_csv('X_train.csv') #remove the headline automatically
Y_set = pd.read_csv('Y_train.csv')
print(X_set.shape, Y_set.shape)
print(X_set.head(3)) #to check whether data read correctlly, return the first 3 rows of datasets
# Out:
# (1212, 833) (1212, 2)
#     id         x0             x1            x2           x3            x4  \
# 0  0.0  10.891876  832442.812375  20585.544083  1028.369495  1.163780e+06
# 1  1.0  11.512994  832442.898114           NaN  1012.624877  1.028911e+06
# 2  2.0  11.052185  832442.896307  20585.512844  1003.953827  9.231756e+05
#
#           x5             x6            x7            x8  ...          x822  \
# 0   9.199135  597900.477629           NaN  1.144294e+06  ...  1.024198e+06
# 1  10.906408  597900.458612   8127.016078  1.099166e+06  ...  1.086806e+06
# 2   9.212979  597900.426764  10738.092422  1.027863e+06  ...  1.018533e+06
#
#          x823          x824       x825       x826         x827       x828  \
# 0 -855.549602  12176.073427  10.647729  10.916371  1220.065443   8.566724
# 1 -787.397942  10493.095660  10.586492   9.463962   917.094909  10.231822
# 2 -906.997242  10959.516944  10.769287  10.342160   637.027802  10.705461
#
#            x829          x830           x831
# 0  1.036263e+06  85338.558539  103088.664210
# 1  1.007163e+06  95695.020645  105161.109422
# 2  1.019955e+06  80253.299882  104177.051666
#
# [3 rows x 833 columns]

# %%
# print(X_set.describe()) #show some statistics of dataset

# %%
# separate the other attributes from the predicting attribute
X_set = X_set.drop(['id'], axis=1) #remove the id column
Y_set = Y_set['y'] #remove the id column

X_set.shape
# Out:
# (1212, 832)

# %% [markdown]
# ## Dataset processing

# %%
# do Normalization
X_set = (X_set-X_set.min())/(X_set.max()-X_set.min())
# another normalization method
# X_set = (X_set-X_set.mean())/X_set.std()   
print(X_set)
# Out:
#             x0        x1        x2        x3        x4        x5        x6  \
# 0     0.671513  0.038048  0.704819  0.283301  0.742406  0.384317  0.968128
# 1     0.770354  0.897546       NaN  0.125719  0.535428  0.680530  0.777597
# 2     0.697023  0.879426  0.391507  0.038934  0.373160  0.386719  0.458500
# 3     0.790895       NaN       NaN  0.046123  0.408105  0.445786  0.694986
# 4     0.594372  0.229011  0.834443       NaN  0.484488  0.248992  0.427188
# ...        ...       ...       ...       ...       ...       ...       ...
# 1207  0.512910  0.749474  0.370751  0.826649  0.655298  0.682115  0.785874
# 1208  0.503857  0.075726  0.569900  0.207702  0.465629       NaN  0.476504
# 1209  0.412992  0.071248  0.521564  0.766654  0.130666  0.450372       NaN
# 1210       NaN  0.181724  0.905143  0.763612  0.388574  0.326126  0.217794
# 1211  0.381720  0.331962  0.582712  0.779807  0.424843  0.678536  0.657705
#
#             x7        x8        x9  ...      x822      x823      x824  \
# 0          NaN  0.791909  0.250335  ...  0.241736  0.563679  0.432692
# 1     0.327139  0.725075  0.821083  ...  0.869915  0.615437  0.357152
# 2     0.517681  0.619477  0.472322  ...  0.184891  0.524607  0.378087
# 3     0.720988  0.827230  0.786720  ...  0.470693  0.445058  0.642270
# 4     0.675011  0.671809  0.146022  ...  0.310078  0.434820  0.709739
# ...        ...       ...       ...  ...       ...       ...       ...
# 1207       NaN  0.607976  0.654254  ...  0.047705  0.454402  0.680156
# 1208  0.525267  0.741592  0.995407  ...  0.809751  0.368103  0.604062
# 1209       NaN  0.714951  0.652168  ...  0.470647  0.847312  0.404124
# 1210  0.691575  0.318448  0.552454  ...  0.706973  0.405634  0.564322
# 1211  0.459956  0.593125  0.335374  ...  0.637710  0.561992  0.537278
#
#           x825      x826      x827      x828      x829      x830      x831
# 0     0.589777  0.609244  0.445293  0.313577  0.362915  0.211016  0.308463
# 1     0.533112  0.392115  0.258967  0.562242  0.071669  0.391171  0.516304
# 2     0.702259  0.523402  0.086727  0.632975  0.199699  0.122556  0.417615
# 3     0.438115  0.561191  0.380106  0.575570  0.855114       NaN  0.274150
# 4          NaN       NaN  0.451457  0.564971  0.248307  0.497643  0.516569
# ...        ...       ...       ...       ...       ...       ...       ...
# 1207  0.427438  0.441239  0.463148  0.667999  0.929655  0.420877  0.711812
# 1208  0.239529  0.438058  0.557232  0.670814  0.833300  0.589568  1.000000
# 1209  0.310673  0.526337  0.288434  0.599835  0.078755  0.798993  0.524254
# 1210  0.759479  0.497333       NaN  0.624388  0.479011  0.548530  0.026039
# 1211  0.279227  0.264210  0.455739       NaN  0.299172       NaN  0.444806
#
# [1212 rows x 832 columns]

# %%
#use each col's mean to fill the NAN default value
X_set = X_set.fillna(X_set.mean())
print(X_set)
# Out:
#             x0        x1        x2        x3        x4        x5        x6  \
# 0     0.671513  0.038048  0.704819  0.283301  0.742406  0.384317  0.968128
# 1     0.770354  0.897546  0.512296  0.125719  0.535428  0.680530  0.777597
# 2     0.697023  0.879426  0.391507  0.038934  0.373160  0.386719  0.458500
# 3     0.790895  0.508350  0.512296  0.046123  0.408105  0.445786  0.694986
# 4     0.594372  0.229011  0.834443  0.489366  0.484488  0.248992  0.427188
# ...        ...       ...       ...       ...       ...       ...       ...
# 1207  0.512910  0.749474  0.370751  0.826649  0.655298  0.682115  0.785874
# 1208  0.503857  0.075726  0.569900  0.207702  0.465629  0.538017  0.476504
# 1209  0.412992  0.071248  0.521564  0.766654  0.130666  0.450372  0.490470
# 1210  0.533732  0.181724  0.905143  0.763612  0.388574  0.326126  0.217794
# 1211  0.381720  0.331962  0.582712  0.779807  0.424843  0.678536  0.657705
#
#             x7        x8        x9  ...      x822      x823      x824  \
# 0     0.492254  0.791909  0.250335  ...  0.241736  0.563679  0.432692
# 1     0.327139  0.725075  0.821083  ...  0.869915  0.615437  0.357152
# 2     0.517681  0.619477  0.472322  ...  0.184891  0.524607  0.378087
# 3     0.720988  0.827230  0.786720  ...  0.470693  0.445058  0.642270
# 4     0.675011  0.671809  0.146022  ...  0.310078  0.434820  0.709739
# ...        ...       ...       ...  ...       ...       ...       ...
# 1207  0.492254  0.607976  0.654254  ...  0.047705  0.454402  0.680156
# 1208  0.525267  0.741592  0.995407  ...  0.809751  0.368103  0.604062
# 1209  0.492254  0.714951  0.652168  ...  0.470647  0.847312  0.404124
# 1210  0.691575  0.318448  0.552454  ...  0.706973  0.405634  0.564322
# 1211  0.459956  0.593125  0.335374  ...  0.637710  0.561992  0.537278
#
#           x825      x826      x827      x828      x829      x830      x831
# 0     0.589777  0.609244  0.445293  0.313577  0.362915  0.211016  0.308463
# 1     0.533112  0.392115  0.258967  0.562242  0.071669  0.391171  0.516304
# 2     0.702259  0.523402  0.086727  0.632975  0.199699  0.122556  0.417615
# 3     0.438115  0.561191  0.380106  0.575570  0.855114  0.462552  0.274150
# 4     0.503751  0.480886  0.451457  0.564971  0.248307  0.497643  0.516569
# ...        ...       ...       ...       ...       ...       ...       ...
# 1207  0.427438  0.441239  0.463148  0.667999  0.929655  0.420877  0.711812
# 1208  0.239529  0.438058  0.557232  0.670814  0.833300  0.589568  1.000000
# 1209  0.310673  0.526337  0.288434  0.599835  0.078755  0.798993  0.524254
# 1210  0.759479  0.497333  0.350630  0.624388  0.479011  0.548530  0.026039
# 1211  0.279227  0.264210  0.455739  0.528857  0.299172  0.462552  0.444806
#
# [1212 rows x 832 columns]

# %%
print("X_set.shape:", X_set.shape)
print("Y_set.shape:", Y_set.shape)
# Out:
# X_set.shape: (1212, 832)
# Y_set.shape: (1212,)

# %% [markdown]
# ## Regression Method

# %%
LR = LinearRegression()


#X_set.isnull().sum()
X_set.isnull().sum()
X_set.shape
#print(X_set)
#print("\n\n",Y_set)
#LR.fit(X_set,Y_set)
# y_prediction = LR.predict(test)
# Out:
# (1212, 832)
